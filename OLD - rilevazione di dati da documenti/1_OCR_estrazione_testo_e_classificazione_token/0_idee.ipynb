# %% [markdown]
# # Raccolta di idee e considerazioni su AI e Documenti

# %% [markdown]
# Prova n.1 (LayoutLMv3)
# - Dovrebbe includere parte di riconoscimento testo e posizione, quindi se funzionasse, basta il modello LayoutLMv3 e un modello che fa NER(Named Entity Recognition).

# %% [markdown]
# - primo Step:  (FATTO)
#
#  1. Addestramento / Fine-tuning di LLMv3
#  2. Dataset: FUNSD
#  3. VALUTAZIONE diretta su test set FUNSD

# %% [markdown]
# - Step intermendio: creazione dataset (estratti conto): https://labelstud.io/
#
# - (non ancora fatto, richeide molto tempo)
#
# - Per annotare documenti mulipagina: https://labelstud.io/templates/multi-page-document-annotation

# %% [markdown]
# - secondo Step
#
# 1. Addestramento / Fine-tuning di LLMv3
# 2. Dataset: DATASET PERSONALE (o entrambi con Fine-Tuning)--> le etichette sono diverse però
# 3. VALUTAZIONE diretta su test set Hype

# %% [markdown]
# -------------------------------------------------------------------------

# %% [markdown]
# Prova n. 2 (OCR di base e NLP - NER)
#
# - Non dobbiamo creare il dataset di docuemnti etichettati (molto dispendioso), ma difficilemnte il modello funzionerà bene.

# %% [markdown]
# - primo step
#
# 1. Capire come addestrare un modello NLP secondo le nostre esigenze --> NER o Universal NER
# 2. Testare i modelli presenti su Hugging Face (lingua italiana)
# 2. Provare i comandi della libreria SpaCy e i vari Annotator online (link su OneNote) per addestrare i modelli

# %% [markdown]
# - secondo step
#
# 1. Addestrare e testare il modello sul testo estratto dai docuemnti/immagini usando librerie e OCR

# %% [markdown]
# - Esempio di problema:
#
# Discriminare correttamente che un nome contenunto nella descrizione di un bonifico, faccia solo parte della descrizone e che non sia l'intestarario del conto... e tutti i casi simili. Per questo servirebbe entra in gioco l'utilita del modello LayoutLMv3

# %% [markdown]
# ----------------------------------------------------------------------------------

# %% [markdown]
# Altre idee:

# %% [markdown]
# 1. Affidarsi ad un Trasformer già addestrato e molto potente come GTP, Gemini ecc. Tramite chiamate API, andiamo ad interrogare il modello chiedendo di estratte le informazioni che rispettano un determianto "extraction schema".
#
# 2. Utilizzo modello LayoutLMv3, dobbiamo addestrarlo su un altro daatset e provare il fine tuning con i nostri dati, oppure addestrarlo direttamente sui nostri dati (non credo siano suffcienti), etichettiamo i dodcuemnti con LabelStudio.
#
# 3. Addestrare un NLP persoanle, in grado di fare NER in modo efficacie, usare NER annotator per creare il dataset.
